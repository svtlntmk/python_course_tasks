# %% [markdown]
# # Домашнє завдання до лекції 3: Pandas

# %% [markdown]
# У цьому домашньому завданні ми працюємо з набором даних про продажі в різних магазинах мережі супермаркетів. Дані взяті з Kaggle, за [посиланням](https://www.kaggle.com/aungpyaeap/supermarket-sales) Ви можете знайти їх опис. Прочитати опис даних - хороша практика перед початком роботи, тож дуже раджу це зробити :)Завантажте дані з навчальної платформи собі локально. Накраще це зробити в окрему директорію `/data` на вашому компʼютері (папка `data/` мє бути в тій самій папці, де і цей ноутбук). Дані ми не заливаємо зазвичай в git, особливо якщо вони більше 10мб - це погана практика. Ліпше залити на гугл диск і дати посилання в репозиторії в readme, якщо дані великі.
#
# У цьому домашньому завданні особливо важливо **уважно** читати формулювання завдання і всі коментарі.
# В цьому домашньому завданні також треба по максимуму використовувати функціонал бібліотеки pandas, навіть якщо існують альтернативні способи зробити те саме.
#
# УВАГА! В даному наборі даних ми будемо розуміти кожен рядок (унікальний Invoice ID) як одне **відвідування супермаркету**.

# %% [markdown]
# 1.За допомогою бібліотеки Pandas, викликом однієї функції зчитайте набір даних із файлу 'supermarket_sales.csv'.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../Datasets/Supermarket Sales/supermarket_sales_2.csv')

# %% [markdown]
# 2.За допомогою бібліотеки Pandas виведіть перші 4 і останні 4 записи у наборі даних. Треба саме 4! Не 5.

# %%
display(df.head(4))
display(df.tail(4))
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# ...

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 3.Виведіть кількість рядків і кількість колонок в наборі даних. Відповідь сформуйте використовуючи fstring.

# %%
print(f"Набір даних містить {df.shape[0]} рядків та {df.shape[1]} колонок.")
# Out:
# Набір даних містить 1000 рядків та 17 колонок.

# %% [markdown]
# Очікувана відповідь:
#     ```Набір даних містить 1000 рядків та 17 колонок.```

# %% [markdown]
# 4.Виведіть назви колонок у наборі даних разом з їхніми типами.

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![Screenshot%20%286%29.png](attachment:Screenshot%20%286%29.png)

# %% [markdown]
# 5.Скільки в даному наборі даних є колонок якого типу (текстового, int, float)?

# %%
df.dtypes.value_counts()
# Out:
# object     9
# float64    7
# int64      1
# Name: count, dtype: int64

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![Screenshot%20%287%29.png](attachment:Screenshot%20%287%29.png)

# %% [markdown]
# 6.Скільки всього відвідувань (кількість інвойсів) зробили покупці з різним типом клієнта (`Customer type`)? Тут можна отримати відповідь одним рядком коду і це варіант реалізації, якому варто надати перевагу.

# %%
df["Customer type"].value_counts()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %% [markdown]
# Очікуваний результат може бути одного з наступних виглядів:

# %% [markdown]
# ![Screenshot%20%288%29.png](attachment:Screenshot%20%288%29.png)

# %% [markdown]
# 7.Які є продуктові лінії (колонка 'Product line') в наборі даних? Вивести унікальні назви. Результат може бути в форматі np.array, list, pd.Series - це не грає великої ролі тут. Але знову ж таки пріоритет на отриманні результату одним методом :)

# %%
df["Product line"].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %% [markdown]
# Очікуваний результат (формат даних може бути інший, але категорії мають бути такі самі):

# %% [markdown]
# ![Screenshot%20%289%29.png](attachment:Screenshot%20%289%29.png)

# %% [markdown]
# 8.Яка середня ціна товару в кожній продуктовій лінії?
# Ціна товару міститься в колонці `'Unit price'`

# %%
df.groupby('Product line')['Unit price'].mean()
# Out:
# Product line
# Electronic accessories    53.551588
# Fashion accessories       57.153652
# Food and beverages        56.008851
# Health and beauty         54.854474
# Home and lifestyle        55.316937
# Sports and travel         56.993253
# Name: Unit price, dtype: float64

# %% [markdown]
# Очікуваний результат (бажано в такому ж форматі - тип pd.Series):

# %% [markdown]
# ![Screenshot%20%2810%29.png](attachment:Screenshot%20%2810%29.png)

# %% [markdown]
# 9.З якого інвойсу (рядок в цих даних) магазин отримав найбільший прибуток (`gross income`)? Виведіть рядок даних з найбільшим прибутком магазину.

# %%
df.loc[df["gross income"].idxmax()]
# Out:
# Invoice ID                         860-79-0874
# Branch                                       C
# City                                 Naypyitaw
# Customer type                           Member
# Gender                                  Female
# Product line               Fashion accessories
# Unit price                                99.3
# Quantity                                    10
# Tax 5%                                   49.65
# Total                                  1042.65
# Date                                 2/15/2019
# Time                                     14:53
# Payment                            Credit card
# cogs                                     993.0
# gross margin percentage               4.761905
# gross income                             49.65
# Rating                                     6.6
# Name: 350, dtype: object

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 10.А який філіал магазину ('Branch') є найприбутковішим? Який сумарний прибуток він має та в якому місті знайходиться? Може в тому місці нам розмітисти ще один магазин.
# Порахуйте результат з допомогою функціоналу Pandas та виведіть використовуючи fstring форматування.

# %%
the_most_profitable_branch = df.groupby('Branch')['gross income'].sum().idxmax()
branch_city = (
    df[
        df["Branch"] == the_most_profitable_branch
    ]["City"].unique()[0])

print(f"Філіал {the_most_profitable_branch} є найприбутковішим. Цей філіал знаходиться в місті {branch_city}.")
# Out:
# Філіал C є найприбутковішим. Цей філіал знаходиться в місті Naypyitaw.

# %% [markdown]
# Очікуваний результат: `Філіал "C" є найприбутковішим. Цей філіал знаходиться в місті Naypyitaw.`

# %% [markdown]
# 11.Перевірте програмно, чи відрізняється маржа ('gross margin percentage') для різних відвідувань (інвойсів) в магазині? Дайте на основі отриманого результату відповідь: "У всіх всіх відвідувань однакова маржа" або "Маржа відрізняється для різних відвідувань".

# %%
unique_margin_per_invoice = df.groupby('Invoice ID')['gross margin percentage'].nunique()

if len(unique_margin_per_invoice.unique()) == 1:
    print("У всіх відвідувань однакова маржа")
else:
    print("Маржа відрізняється для різних відвідувань")
# Out:
# У всіх відвідувань однакова маржа

# %% [markdown]
# 12.В якому філіалі магазину ('Branch') найбільше відвідувань (інвойсів) із покупкою електронних аксесуарів ('Electronic accessories')? Electronic accessories - це одна з продуктових ліній. Для відповіді сформуйте таблицю в якої рядки - це назви філіалів, колонки - це назви продуктової лінійки, а значення - це кількість відвідувань, під час яких була покупка електронних аксесуарів (тобто це кількість рядків у даних). Дайте відповідь базуючись на сформованій таблиці. Можна просто візуально.

# %%
df.pivot_table(index=['Branch'], columns=['Product line'], values=['Invoice ID'], aggfunc='count')
# Out:
#                          Invoice ID                                         \
# Product line Electronic accessories Fashion accessories Food and beverages
# Branch
# A                                60                  51                 58
# B                                55                  62                 50
# C                                55                  65                 66
#
#
# Product line Health and beauty Home and lifestyle Sports and travel
# Branch
# A                           47                 65                59
# B                           53                 50                62
# C                           52                 45                45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![Screenshot%20%2811%29.png](attachment:Screenshot%20%2811%29.png)

# %% [markdown]
# 13.Виведіть кількість відвідувань (інвойсів) погодинно та зробіть висновок, коли в магазині роблять найбільше відвідувань (тут ми розуміємо одне відвідування як один інвойс).
# Для цього створіть нову колонку в наборі даних з назвою Hour. Тип колонки - int. Виведіть тип колонки та перші 5 записів. Далі використовуючи цю колонку, сформуйте структуру, де кожній годині відповідає кількість інвойсів. З огляду на цю структуру дайте відповідь, о якій годині найбільше було відвідувань (інвойсів). Дивлячись на найбільш популярні для відвідувань години, які гіпотези про поведінку користувачів можемо зробити? Чому вони найчастіше купують саме в цей час?

# %%
df['Hour'] = df['Time'].apply(lambda x: int(x.split(':')[0]))
df['Hour'].head(5)
df.groupby('Hour')['Invoice ID'].count()

''' 
Гіпотеза № 1: найбільш попуярні для відвідування години, тобто 10, 13 та 15 можуть відповідати перервам на роботі (на обід чи перекус).
В залежності від того о котрій годині людина починає свій робочий день, ці години можуть відрізнятися. 
Так для когось, хто починає роботу о 7 чудовим часом для короткої переви може бути 10.
Або ж людина починає роботу о 9, розгрібає мейли, робить план на день і о 10 йде на каву)

Гіпотеза № 2: 18-19 - це післярообочий час, коли працівники добираються додому.
Вони можуть використовувати час у транспорті для того, щоб здійснити якісь покупки.
Або ж це може бути час за вечерею, коли покупець має час переглянути асортимент товарів.

Гіпотеза № 3: найпопулярніші години - це час, коли магазин активує знижки та інші класні пропозиції для клієнтів,
що призводить до напливу користувачів саме в цей час.
'''
# Out:
# Hour
# 10    101
# 11     90
# 12     89
# 13    103
# 14     83
# 15    102
# 16     77
# 17     74
# 18     93
# 19    113
# 20     75
# Name: Invoice ID, dtype: int64

# %% [markdown]
# Очікуваний результат наступний і після цього має бути ваша відповідь на питання в цьому завданні. Просто текстом.

# %% [markdown]
# ![Screenshot%20%2812%29.png](attachment:Screenshot%20%2812%29.png)

# %% [markdown]
# 14. Творче завдання :) Сформулюйте ТРИ питання до наявних даних, які допомогли б вам зрозуміти які користувачі що, де та коли найбільше/найменше купують. Звісно питання мають бути не тими, на які ми вже відповіли вище.
#     Дайте відповіді на свої питання з допомогою функціоналу pandas. Опціонально - написати, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#     Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат.

# %%
# 1. Яка середня оцінка філіалів? Роботу якого з філіалів користувачі оцінюють найгірше?
display(df.groupby("Branch")['Rating'].mean().sort_values())

print(f"Відповідь на це запитання дозволить оцінити якість сервісу та виявити, як клієнти оцінюють роботу окремих філіалів і на який з них варто звернути увагу та внести певні зміни. Покращення сервісу, спрощення процедури купівлі товару, збільшення/зміна штату працівників, оцінка умов роботи філіалів - все це може вплинути на враження клієнтів і заохотити до здійснення покупок саме в цьому магазині")
# Out:
# Branch
# B    6.818072
# A    7.027059
# C    7.072866
# Name: Rating, dtype: float64
# Відповідь на це запитання дозволить оцінити якість сервісу та виявити, як клієнти оцінюють роботу окремих філіалів і на який з них варто звернути увагу та внести певні зміни. Покращення сервісу, спрощення процедури купівлі товару, збільшення/зміна штату працівників, оцінка умов роботи філіалів - все це може вплинути на враження клієнтів і заохотити до здійснення покупок саме в цьому магазині

# %%
# 2. Які категорії товарів є найменш та найбільш популярними серед жінок та чоловіків?
display(df.groupby(["Gender", "Product line"])["gross income"].count())

print(f"Такі дані допомогли б нам краще достосувати асортимент до потреб окремих греп користувачів. Наприклад, тут маємо інформацію, що найменше товарів жінки купують з категорії Health and beauty. Хоча б здавалося, що це більш 'жіноча' категорія. Можливо представлений асортимент не задовлільняє потреби коричтувачів?")
# Out:
# Gender  Product line
# Female  Electronic accessories    84
#         Fashion accessories       96
#         Food and beverages        90
#         Health and beauty         64
#         Home and lifestyle        79
#         Sports and travel         88
# Male    Electronic accessories    86
#         Fashion accessories       82
#         Food and beverages        84
#         Health and beauty         88
#         Home and lifestyle        81
#         Sports and travel         78
# Name: gross income, dtype: int64
# Такі дані допомогли б нам краще достосувати асортимент до потреб окремих греп користувачів. Наприклад, тут маємо інформацію, що найменше товарів жінки купують з категорії Health and beauty. Хоча б здавалося, що це більш 'жіноча' категорія. Можливо представлений асортимент не задовлільняє потреби коричтувачів?

# %%
# 3. Які категорії продуктів приносять найменший прихід в філіалах?
display(df.groupby(["Branch", "Product line"])["gross income"].sum())
print(f"Інформація про прибутки з поділом на категорії допоможе достосувати асортимент в філіалах. Можна провести додаткове дослідження і визначити чи прибутки для цієї категорії є низькими через низьку вартість продукту чи через малу кількість покупок. А можливо саме в даному філіалі/локації потрібно змінити асортимент")
# Out:
# Branch  Product line
# A       Electronic accessories     872.2435
#         Fashion accessories        777.7385
#         Food and beverages         817.2905
#         Health and beauty          599.8930
#         Home and lifestyle        1067.4855
#         Sports and travel          922.5095
# B       Electronic accessories     811.9735
#         Fashion accessories        781.5865
#         Food and beverages         724.5185
#         Health and beauty          951.4600
#         Home and lifestyle         835.6745
#         Sports and travel          951.8190
# C       Electronic accessories     903.2845
#         Fashion accessories       1026.6700
#         Food and beverages        1131.7550
#         Health and beauty          791.2060
#         Home and lifestyle         661.6930
#         Sports and travel          750.5680
# Name: gross income, dtype: float64
# ...
